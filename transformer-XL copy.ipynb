# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from torch.utils.data import DataLoader, Dataset

def load_data(file_path):
    user_dict = {}
    with open(file_path, 'r') as f:
        for line in f:
            user, item = map(int, line.strip().split())
            if user not in user_dict:
                user_dict[user] = []
            user_dict[user].append(item)
    return user_dict

class RecDataset(Dataset):
    def __init__(self, user_dict, num_items, max_seq_length, segment_length):
        self.data = []
        for user, items in user_dict.items():
            if len(items) < 2:
                continue
            
            # items = items[:-1] #remove the last item as it can be used during evaluation time
            if len(items)<max_seq_length:
                items = [0]*(max_seq_length+1-len(items)) + items
                
            
            seq = items[:max_seq_length+1]  #first max_seq_length items
            for i in range(0, len(seq) - 1, segment_length):
                segment = seq[i:i+segment_length]
                target = seq[i+1:i+1+segment_length]
                negative = random.sample(set(range(num_items)) - set(target), segment_length) # This is a simple negative sampling strategy which samples items that are not in the target set
                if len(segment) == segment_length and len(target) == segment_length:
                    self.data.append((segment, target, negative))
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return torch.tensor(self.data[idx][0], dtype=torch.long), torch.tensor(self.data[idx][1], dtype=torch.long), torch.tensor(self.data[idx][2], dtype=torch.long)


# Example usage

device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

embed_dim = 32
num_layers = 1
num_heads = 8
hidden_dim = 32
mem_length = 100
max_seq_length = 250
segment_length = 250
batch_size = 32
num_epochs = 10

# Load data

file_path = "data/tracks256_mapped.txt"
user_dict = load_data(file_path)
num_items = max(max(items) for items in user_dict.values()) + 1
print("Number of users: ", len(user_dict))
print("Number of items: ", num_items)   
train_dataset = RecDataset(user_dict, num_items, max_seq_length, segment_length)

print("Number of training samples: ", len(train_dataset))
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,drop_last=True)

for segment, target , negatives in train_loader:
    print(segment.shape)
    print(target.shape)
    print(negatives.shape)
    break
    
# if the last batch is smaller than batch_size, the last batch will be dropped
# Out:
# Number of users:  25001
# Number of items:  2225191
# Number of training samples:  24994
# torch.Size([32, 250])
# torch.Size([32, 250])
# torch.Size([32, 250])

# %%
import torch
from torch import nn

from labml.logger import inspect
from labml_nn.transformers.mha import MultiHeadAttention


from typing import List, Optional
def shift_right(x: torch.Tensor):
    """
    This method shifts $i^{th}$ row of a matrix by $i$ columns.

    If the input is `[[1, 2 ,3], [4, 5 ,6], [7, 8, 9]]`, the shifted
    result would be `[[1, 2 ,3], [0, 4, 5], [6, 0, 7]]`.
    *Ideally we should mask out the lower triangle but it's ok for our purpose*.
    """

    # Concatenate a column of zeros
    zero_pad = x.new_zeros(x.shape[0], 1, *x.shape[2:])
    x_padded = torch.cat([x, zero_pad], dim=1)

    # Reshape and remove excess elements from the end
    x_padded = x_padded.view(x.shape[1] + 1, x.shape[0], *x.shape[2:])
    x = x_padded[:-1].view_as(x)

    #
    return x



class RelativeMultiHeadAttention(MultiHeadAttention):
   

    def __init__(self, heads: int, d_model: int, dropout_prob: float = 0.1):
        # The linear transformations do not need a bias since we
        # explicitly include it when calculating scores.
        # However having a bias for `value` might make sense.
        # print(heads, d_model, dropout_prob)
        super().__init__(heads, d_model, dropout_prob, bias=False)
        
        # Number of relative positions
        self.P = 2 ** 12

        # Relative positional embeddings for key relative to the query.
        # We need $2P$ embeddings because the keys can be before or after the query.
        self.key_pos_embeddings = nn.Parameter(torch.zeros((self.P * 2, heads, self.d_k)), requires_grad=True)
        # Relative positional embedding bias for key relative to the query.
        self.key_pos_bias = nn.Parameter(torch.zeros((self.P * 2, heads)), requires_grad=True)
        # Positional embeddings for the query is independent of the position of the query
        self.query_pos_bias = nn.Parameter(torch.zeros((heads, self.d_k)), requires_grad=True)

    def get_scores(self, query: torch.Tensor, key: torch.Tensor):
        

        # $\textcolor{orange}{R_k}$
        key_pos_emb = self.key_pos_embeddings[self.P - key.shape[0]:self.P + query.shape[0]]
        # $\textcolor{orange}{S_k}$
        key_pos_bias = self.key_pos_bias[self.P - key.shape[0]:self.P + query.shape[0]]
        # $\textcolor{orange}{v^\top}$
        query_pos_bias = self.query_pos_bias[None, None, :, :]

        # ${(\textcolor{lightgreen}{\mathbf{A + C}})}_{i,j} =
        # Q_i^\top K_j +
        # \textcolor{orange}{v^\top} K_j$
        ac = torch.einsum('ibhd,jbhd->ijbh', query + query_pos_bias, key)
        # $\textcolor{lightgreen}{\mathbf{B'}_{i,k}} = Q_i^\top \textcolor{orange}{R_k}$
        b = torch.einsum('ibhd,jhd->ijbh', query, key_pos_emb)
        # $\textcolor{lightgreen}{\mathbf{D'}_{i,k}} = \textcolor{orange}{S_k}$
        d = key_pos_bias[None, :, None, :]
        # Shift the rows of $\textcolor{lightgreen}{\mathbf{(B' + D')}_{i,k}}$
        # to get $$\textcolor{lightgreen}{\mathbf{(B + D)}_{i,j} = \mathbf{(B' + D')}_{i,i - j}}$$
        bd = shift_right(b + d)
        # Remove extra positions
        bd = bd[:, -key.shape[0]:]

      
        return ac + bd

# %%
class TransformerXLLayer(nn.Module):
    def __init__(self, d_model: int, self_attn: RelativeMultiHeadAttention, dropout_prob: float):
        super().__init__()
        self.size = d_model
        self.self_attn = self_attn
        self.linear = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout_prob)
        self.norm_self_attn = nn.LayerNorm(d_model)
        self.norm_linear = nn.LayerNorm(d_model)

    def forward(self, x: torch.Tensor, mem: Optional[torch.Tensor], mask: torch.Tensor):
        z = self.norm_self_attn(x)
        if mem is not None:
            mem = self.norm_self_attn(mem)
            
            m_z = torch.cat((mem, z), dim=0)
        else:
            m_z = z
        self_attn = self.self_attn(query=z, key=m_z, value=m_z, mask=mask)
        x = x + self.dropout(self_attn)
        z = self.norm_linear(x)
        linear_out = self.linear(z)
        x = x + self.dropout(linear_out)
        return x

class TransformerXL(nn.Module):
    def __init__(self, layer: TransformerXLLayer, n_layers: int):
        super().__init__()
        self.layers = nn.ModuleList([layer for _ in range(n_layers)])
        self.norm = nn.LayerNorm(layer.size)

    def forward(self, x: torch.Tensor, mem: List[torch.Tensor], mask: torch.Tensor):
        new_mem = []
        for i, layer in enumerate(self.layers):
            new_mem.append(x.detach())
            m = mem[i] if mem else None
            x = layer(x=x, mem=m, mask=mask)
        return self.norm(x), new_mem

class TransformerXLEncoder(nn.Module):
    def __init__(self, num_items, embed_dim, num_layers, num_heads, hidden_dim, mem_length, dropout=0.1):
        super().__init__()
        self.embedding = nn.Embedding(num_items, embed_dim)
        self.mem_length = mem_length
        # print(embed_dim)
        self.transformer = TransformerXL(
            TransformerXLLayer(
                d_model=embed_dim,
                self_attn=RelativeMultiHeadAttention(num_heads,embed_dim, dropout),
                dropout_prob=dropout
            ),
            n_layers=num_layers
        )
        self.linear = nn.Linear(embed_dim, num_items)
    
    def forward(self, x, memory=None):
        x = self.embedding(x)  # Shape: (B, S, D)
        x = x.permute(1, 0, 2)  # Shape: (S, B, D)
        mask = None  # Define mask if needed
        output, new_memory = self.transformer(x, memory, mask)  # Shape: (S, B, D)
        # logits = self.linear(output)  # Shape: (S, B, num_items)
        # return logits.permute(1, 2, 0), new_memory  # Shape: (B, num_items, S)
        return output.permute(1, 0, 2), new_memory
    
    
#example usage
# x = torch.randint(0, num_items, (batch_size, segment_length), dtype=torch.long).to(device)
# model = TransformerXLEncoder(num_items, embed_dim, num_layers, num_heads, hidden_dim, mem_length).to(device)
# logits, memory = model(x)
# print(logits.shape)

# %%
def train_model(model, train_loader, optimizer, criterion, device, num_epochs=10):
    bce_criterion = nn.BCEWithLogitsLoss()
    model.train()
    memory = None  # Initialize memory

    for epoch in range(num_epochs):
        total_loss = 0

        for inputs, targets ,negatives in train_loader:
            inputs, targets,negatives = inputs.to(device), targets.to(device), negatives.to(device)
            optimizer.zero_grad()
             
            # logits, memory = model(inputs, memory)  # Pass both sequence & memory
            outputs, memory = model(inputs, memory)
            pos_emb = model.embedding(targets) # Shape: (B, S, D)
            neg_emb = model.embedding(negatives)
            
            pos_logits = torch.einsum('bsd,bsd->bs', outputs, pos_emb)
            neg_logits = torch.einsum('bsd,bsd->bs', outputs, neg_emb)
            target = torch.ones_like(pos_logits,device=device)
            neg = torch.zeros_like(neg_logits,device=device)
            
            indices = np.where(targets.cpu().numpy() != 0)
            
            loss = bce_criterion(pos_logits[indices], target[indices])
            loss += bce_criterion(neg_logits[indices], neg[indices])
            
            # print(logits.shape, targets.shape)
            # loss = criterion(logits, targets)  # Shape: (B, num_items, S)
            # loss = bce_criterion(outputs, target)

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"Epoch {epoch+1}, Loss: {total_loss / len(train_loader):.4f}")

# %%
def evaluate(model, user_dict, num_items, max_seq_length, segment_length, device):
    model.eval()
    NDCG, HR, valid_users = 0.0, 0.0, 0
    
    for user, items in user_dict.items():
        if len(items) < 2:
            continue
        
        seq = items[:max_seq_length]
        input_seq = torch.tensor(seq[:-1], dtype=torch.long).unsqueeze(0).to(device)
        target = seq[-1]
        candidates = [target] + random.sample(set(range(1, num_items)) - set(items), 99)
        
        memory = None
        for i in range(0, len(input_seq[0]), segment_length):
            segment = input_seq[:, i:i+segment_length]
            logits, memory = model(segment, memory)
            
        # logits shape is (1, num_items, segment_length)
        # logits shape is (1,segment_length, embed_dim)
        last_logits = logits[0, -1, :] # shape is embed_dim
        candidate_emb = model.embedding(torch.tensor(candidates, dtype=torch.long).to(device))
        scores = torch.einsum('d,cd->c', last_logits, candidate_emb)
        ranked = torch.argsort(scores, descending=True).cpu().numpy() # shape is 100
        
        
        # scores = logits[0, :, -1]
        # scores = scores[candidates]
        # # print(scores)
        # ranked = torch.argsort(scores, descending=True).cpu().numpy()
        rank = np.where(ranked == 0)[0][0] + 1
        # print(rank)
        valid_users += 1
        
        
        HR += int(rank <= 10)
        NDCG += 1 / np.log2(rank + 1) if rank <= 10 else 0
        
        if valid_users % 10 == 0:
            print(f"Validated users: {valid_users}, HR@10: {HR / valid_users:.4f}, NDCG@10: {NDCG / valid_users:.4f}")
    print(f"HR@10: {HR / valid_users:.4f}, NDCG@10: {NDCG / valid_users:.4f}")

# %%
model = TransformerXLEncoder(num_items, embed_dim, num_layers, num_heads, hidden_dim, mem_length).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
print(model)
num_epochs=10
train_model(model, train_loader, optimizer, criterion, device, num_epochs)
# Out:
# TransformerXLEncoder(
#   (embedding): Embedding(2225191, 32)
#   (transformer): TransformerXL(
#     (layers): ModuleList(
#       (0): TransformerXLLayer(
#         (self_attn): RelativeMultiHeadAttention(
#           (query): PrepareForMultiHeadAttention(
#             (linear): Linear(in_features=32, out_features=32, bias=False)
#           )
#           (key): PrepareForMultiHeadAttention(
#             (linear): Linear(in_features=32, out_features=32, bias=False)
#           )
#           (value): PrepareForMultiHeadAttention(
#             (linear): Linear(in_features=32, out_features=32, bias=True)
#           )
#           (softmax): Softmax(dim=1)
#           (output): Linear(in_features=32, out_features=32, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (linear): Linear(in_features=32, out_features=32, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm_self_attn): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (norm_linear): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (linear): Linear(in_features=32, out_features=2225191, bias=True)
# )
# Epoch 1, Loss: 2.3300
# Epoch 2, Loss: 0.9954
# Epoch 3, Loss: 0.8535
# Epoch 4, Loss: 0.7967
# Epoch 5, Loss: 0.7572
# Epoch 6, Loss: 0.7203
# Epoch 7, Loss: 0.6785
# Epoch 8, Loss: 0.6277
# Epoch 9, Loss: 0.5675
# Epoch 10, Loss: 0.4991

# %%
evaluate(model, user_dict, num_items, max_seq_length, segment_length, device)
# Out:
# Validated users: 10, HR@10: 0.2000, NDCG@10: 0.2000
# Validated users: 20, HR@10: 0.1500, NDCG@10: 0.1158
# Validated users: 30, HR@10: 0.1000, NDCG@10: 0.0772
# Validated users: 40, HR@10: 0.1750, NDCG@10: 0.1027
# Validated users: 50, HR@10: 0.1600, NDCG@10: 0.0888
# Validated users: 60, HR@10: 0.1500, NDCG@10: 0.0791
# Validated users: 70, HR@10: 0.1429, NDCG@10: 0.0723
# Validated users: 80, HR@10: 0.1250, NDCG@10: 0.0632
# Validated users: 90, HR@10: 0.1222, NDCG@10: 0.0596
# Validated users: 100, HR@10: 0.1200, NDCG@10: 0.0569
# Validated users: 110, HR@10: 0.1182, NDCG@10: 0.0550
# Validated users: 120, HR@10: 0.1250, NDCG@10: 0.0564
# Validated users: 130, HR@10: 0.1231, NDCG@10: 0.0546
# Validated users: 140, HR@10: 0.1286, NDCG@10: 0.0604
# Validated users: 150, HR@10: 0.1267, NDCG@10: 0.0585
# Validated users: 160, HR@10: 0.1375, NDCG@10: 0.0609
# Validated users: 170, HR@10: 0.1412, NDCG@10: 0.0623
# Validated users: 180, HR@10: 0.1333, NDCG@10: 0.0589
# Validated users: 190, HR@10: 0.1263, NDCG@10: 0.0558
# Validated users: 200, HR@10: 0.1300, NDCG@10: 0.0560
# Validated users: 210, HR@10: 0.1286, NDCG@10: 0.0548
# Validated users: 220, HR@10: 0.1318, NDCG@10: 0.0574
# Validated users: 230, HR@10: 0.1304, NDCG@10: 0.0577
# Validated users: 240, HR@10: 0.1333, NDCG@10: 0.0590
# Validated users: 250, HR@10: 0.1400, NDCG@10: 0.0605
# Validated users: 260, HR@10: 0.1346, NDCG@10: 0.0582
# Validated users: 270, HR@10: 0.1333, NDCG@10: 0.0597
# Validated users: 280, HR@10: 0.1286, NDCG@10: 0.0576
# Validated users: 290, HR@10: 0.1276, NDCG@10: 0.0567
# Validated users: 300, HR@10: 0.1367, NDCG@10: 0.0629
# Validated users: 310, HR@10: 0.1355, NDCG@10: 0.0621
# Validated users: 320, HR@10: 0.1344, NDCG@10: 0.0613
# Validated users: 330, HR@10: 0.1424, NDCG@10: 0.0642
# Validated users: 340, HR@10: 0.1412, NDCG@10: 0.0634
# Validated users: 350, HR@10: 0.1371, NDCG@10: 0.0616
# Validated users: 360, HR@10: 0.1417, NDCG@10: 0.0643
# Validated users: 370, HR@10: 0.1378, NDCG@10: 0.0626
# Validated users: 380, HR@10: 0.1395, NDCG@10: 0.0628
# Validated users: 390, HR@10: 0.1385, NDCG@10: 0.0628
# Validated users: 400, HR@10: 0.1375, NDCG@10: 0.0620
# Validated users: 410, HR@10: 0.1366, NDCG@10: 0.0615
# Validated users: 420, HR@10: 0.1405, NDCG@10: 0.0641
# Validated users: 430, HR@10: 0.1442, NDCG@10: 0.0670
# Validated users: 440, HR@10: 0.1432, NDCG@10: 0.0662
# Validated users: 450, HR@10: 0.1422, NDCG@10: 0.0655
# Validated users: 460, HR@10: 0.1457, NDCG@10: 0.0681
# Validated users: 470, HR@10: 0.1489, NDCG@10: 0.0701
# Validated users: 480, HR@10: 0.1521, NDCG@10: 0.0707
# Validated users: 490, HR@10: 0.1551, NDCG@10: 0.0717
# Validated users: 500, HR@10: 0.1520, NDCG@10: 0.0703
# Validated users: 510, HR@10: 0.1510, NDCG@10: 0.0696
# Validated users: 520, HR@10: 0.1538, NDCG@10: 0.0718
# Validated users: 530, HR@10: 0.1528, NDCG@10: 0.0724
# Validated users: 540, HR@10: 0.1537, NDCG@10: 0.0731
# Validated users: 550, HR@10: 0.1509, NDCG@10: 0.0718
# Validated users: 560, HR@10: 0.1536, NDCG@10: 0.0725
# Validated users: 570, HR@10: 0.1544, NDCG@10: 0.0730
# Validated users: 580, HR@10: 0.1552, NDCG@10: 0.0730
# Validated users: 590, HR@10: 0.1542, NDCG@10: 0.0726
# Validated users: 600, HR@10: 0.1567, NDCG@10: 0.0730
# Validated users: 610, HR@10: 0.1557, NDCG@10: 0.0725
# Validated users: 620, HR@10: 0.1532, NDCG@10: 0.0713
# Validated users: 630, HR@10: 0.1540, NDCG@10: 0.0712
# Validated users: 640, HR@10: 0.1516, NDCG@10: 0.0701
# Validated users: 650, HR@10: 0.1508, NDCG@10: 0.0697
# Validated users: 660, HR@10: 0.1500, NDCG@10: 0.0691
# Validated users: 670, HR@10: 0.1522, NDCG@10: 0.0702
# Validated users: 680, HR@10: 0.1500, NDCG@10: 0.0692
# Validated users: 690, HR@10: 0.1522, NDCG@10: 0.0701
# Validated users: 700, HR@10: 0.1514, NDCG@10: 0.0698
# Validated users: 710, HR@10: 0.1493, NDCG@10: 0.0688
# Validated users: 720, HR@10: 0.1486, NDCG@10: 0.0683
# Validated users: 730, HR@10: 0.1466, NDCG@10: 0.0673
# Validated users: 740, HR@10: 0.1459, NDCG@10: 0.0669
# Validated users: 750, HR@10: 0.1493, NDCG@10: 0.0688
# Validated users: 760, HR@10: 0.1500, NDCG@10: 0.0688
# Validated users: 770, HR@10: 0.1481, NDCG@10: 0.0679
# Validated users: 780, HR@10: 0.1474, NDCG@10: 0.0674
# Validated users: 790, HR@10: 0.1456, NDCG@10: 0.0666
# Validated users: 800, HR@10: 0.1462, NDCG@10: 0.0674
# Validated users: 810, HR@10: 0.1469, NDCG@10: 0.0682
# Validated users: 820, HR@10: 0.1476, NDCG@10: 0.0681
# Validated users: 830, HR@10: 0.1482, NDCG@10: 0.0683
# Validated users: 840, HR@10: 0.1488, NDCG@10: 0.0686
# Validated users: 850, HR@10: 0.1506, NDCG@10: 0.0691
# Validated users: 860, HR@10: 0.1512, NDCG@10: 0.0692
# Validated users: 870, HR@10: 0.1494, NDCG@10: 0.0684
# Validated users: 880, HR@10: 0.1477, NDCG@10: 0.0676
# Validated users: 890, HR@10: 0.1483, NDCG@10: 0.0683
# Validated users: 900, HR@10: 0.1489, NDCG@10: 0.0682
# Validated users: 910, HR@10: 0.1495, NDCG@10: 0.0684
# Validated users: 920, HR@10: 0.1500, NDCG@10: 0.0691
# Validated users: 930, HR@10: 0.1516, NDCG@10: 0.0694
# Validated users: 940, HR@10: 0.1511, NDCG@10: 0.0692
# Validated users: 950, HR@10: 0.1526, NDCG@10: 0.0699
# Validated users: 960, HR@10: 0.1531, NDCG@10: 0.0699
# Validated users: 970, HR@10: 0.1557, NDCG@10: 0.0711
# Validated users: 980, HR@10: 0.1571, NDCG@10: 0.0713
# Validated users: 990, HR@10: 0.1576, NDCG@10: 0.0722
# Validated users: 1000, HR@10: 0.1560, NDCG@10: 0.0715
# Validated users: 1010, HR@10: 0.1554, NDCG@10: 0.0711
# Validated users: 1020, HR@10: 0.1539, NDCG@10: 0.0704
# Validated users: 1030, HR@10: 0.1524, NDCG@10: 0.0698
# Validated users: 1040, HR@10: 0.1519, NDCG@10: 0.0695
# Validated users: 1050, HR@10: 0.1524, NDCG@10: 0.0694
# Validated users: 1060, HR@10: 0.1528, NDCG@10: 0.0697
# Validated users: 1070, HR@10: 0.1542, NDCG@10: 0.0699
# Validated users: 1080, HR@10: 0.1537, NDCG@10: 0.0699
# Validated users: 1090, HR@10: 0.1532, NDCG@10: 0.0695
# Validated users: 1100, HR@10: 0.1527, NDCG@10: 0.0692
# Validated users: 1110, HR@10: 0.1514, NDCG@10: 0.0686
# Validated users: 1120, HR@10: 0.1509, NDCG@10: 0.0688
# Validated users: 1130, HR@10: 0.1496, NDCG@10: 0.0682
# Validated users: 1140, HR@10: 0.1518, NDCG@10: 0.0690
# Validated users: 1150, HR@10: 0.1513, NDCG@10: 0.0688
# Validated users: 1160, HR@10: 0.1509, NDCG@10: 0.0685
# Validated users: 1170, HR@10: 0.1513, NDCG@10: 0.0690
# Validated users: 1180, HR@10: 0.1517, NDCG@10: 0.0698
# Validated users: 1190, HR@10: 0.1529, NDCG@10: 0.0705
# Validated users: 1200, HR@10: 0.1517, NDCG@10: 0.0699
# Validated users: 1210, HR@10: 0.1512, NDCG@10: 0.0698
# Validated users: 1220, HR@10: 0.1516, NDCG@10: 0.0697
# Validated users: 1230, HR@10: 0.1504, NDCG@10: 0.0691
# Validated users: 1240, HR@10: 0.1516, NDCG@10: 0.0700
# Validated users: 1250, HR@10: 0.1504, NDCG@10: 0.0695
# Validated users: 1260, HR@10: 0.1500, NDCG@10: 0.0692
# Validated users: 1270, HR@10: 0.1512, NDCG@10: 0.0695
# Validated users: 1280, HR@10: 0.1508, NDCG@10: 0.0694
# Validated users: 1290, HR@10: 0.1504, NDCG@10: 0.0697
# Validated users: 1300, HR@10: 0.1515, NDCG@10: 0.0699
# Validated users: 1310, HR@10: 0.1504, NDCG@10: 0.0694
# Validated users: 1320, HR@10: 0.1492, NDCG@10: 0.0689
# Validated users: 1330, HR@10: 0.1496, NDCG@10: 0.0689
# Validated users: 1340, HR@10: 0.1485, NDCG@10: 0.0684
# Validated users: 1350, HR@10: 0.1481, NDCG@10: 0.0681
# Validated users: 1360, HR@10: 0.1478, NDCG@10: 0.0684
# Validated users: 1370, HR@10: 0.1474, NDCG@10: 0.0682
# Validated users: 1380, HR@10: 0.1471, NDCG@10: 0.0680
# Validated users: 1390, HR@10: 0.1468, NDCG@10: 0.0679
# Validated users: 1400, HR@10: 0.1464, NDCG@10: 0.0678
# Validated users: 1410, HR@10: 0.1454, NDCG@10: 0.0673
# Validated users: 1420, HR@10: 0.1451, NDCG@10: 0.0672
# Validated users: 1430, HR@10: 0.1455, NDCG@10: 0.0677
# Validated users: 1440, HR@10: 0.1458, NDCG@10: 0.0678
# Validated users: 1450, HR@10: 0.1462, NDCG@10: 0.0680
# Validated users: 1460, HR@10: 0.1466, NDCG@10: 0.0684
# Validated users: 1470, HR@10: 0.1456, NDCG@10: 0.0679
# Validated users: 1480, HR@10: 0.1453, NDCG@10: 0.0677
# Validated users: 1490, HR@10: 0.1443, NDCG@10: 0.0673
# Validated users: 1500, HR@10: 0.1453, NDCG@10: 0.0676
# Validated users: 1510, HR@10: 0.1444, NDCG@10: 0.0671
# Validated users: 1520, HR@10: 0.1447, NDCG@10: 0.0671
# Validated users: 1530, HR@10: 0.1451, NDCG@10: 0.0672
# Validated users: 1540, HR@10: 0.1455, NDCG@10: 0.0672
# Validated users: 1550, HR@10: 0.1452, NDCG@10: 0.0670
# Validated users: 1560, HR@10: 0.1455, NDCG@10: 0.0672
# Validated users: 1570, HR@10: 0.1452, NDCG@10: 0.0671
# Validated users: 1580, HR@10: 0.1443, NDCG@10: 0.0667
# Validated users: 1590, HR@10: 0.1453, NDCG@10: 0.0670
# Validated users: 1600, HR@10: 0.1450, NDCG@10: 0.0668
# Validated users: 1610, HR@10: 0.1453, NDCG@10: 0.0668
# Validated users: 1620, HR@10: 0.1451, NDCG@10: 0.0667
# Validated users: 1630, HR@10: 0.1448, NDCG@10: 0.0665
# Validated users: 1640, HR@10: 0.1451, NDCG@10: 0.0665
# Validated users: 1650, HR@10: 0.1461, NDCG@10: 0.0672
# Validated users: 1660, HR@10: 0.1452, NDCG@10: 0.0668
# Validated users: 1670, HR@10: 0.1455, NDCG@10: 0.0672
# Validated users: 1680, HR@10: 0.1446, NDCG@10: 0.0668
# Validated users: 1690, HR@10: 0.1450, NDCG@10: 0.0668
# Validated users: 1700, HR@10: 0.1447, NDCG@10: 0.0667
# Validated users: 1710, HR@10: 0.1444, NDCG@10: 0.0666
# Validated users: 1720, HR@10: 0.1442, NDCG@10: 0.0664
# Validated users: 1730, HR@10: 0.1439, NDCG@10: 0.0664
# Validated users: 1740, HR@10: 0.1431, NDCG@10: 0.0660
# Validated users: 1750, HR@10: 0.1423, NDCG@10: 0.0656
# Validated users: 1760, HR@10: 0.1420, NDCG@10: 0.0655
# Validated users: 1770, HR@10: 0.1418, NDCG@10: 0.0653
# Validated users: 1780, HR@10: 0.1416, NDCG@10: 0.0653
# Validated users: 1790, HR@10: 0.1413, NDCG@10: 0.0655
# Validated users: 1800, HR@10: 0.1411, NDCG@10: 0.0653
# Validated users: 1810, HR@10: 0.1409, NDCG@10: 0.0651
# Validated users: 1820, HR@10: 0.1401, NDCG@10: 0.0648
# Validated users: 1830, HR@10: 0.1393, NDCG@10: 0.0644
# Validated users: 1840, HR@10: 0.1386, NDCG@10: 0.0641
# Validated users: 1850, HR@10: 0.1389, NDCG@10: 0.0641
# Validated users: 1860, HR@10: 0.1382, NDCG@10: 0.0638
# Validated users: 1870, HR@10: 0.1380, NDCG@10: 0.0636
# Validated users: 1880, HR@10: 0.1388, NDCG@10: 0.0639
# Validated users: 1890, HR@10: 0.1386, NDCG@10: 0.0637
# Validated users: 1900, HR@10: 0.1379, NDCG@10: 0.0633
# Validated users: 1910, HR@10: 0.1387, NDCG@10: 0.0637
# Validated users: 1920, HR@10: 0.1380, NDCG@10: 0.0634
# Validated users: 1930, HR@10: 0.1378, NDCG@10: 0.0632
# Validated users: 1940, HR@10: 0.1397, NDCG@10: 0.0642
# Validated users: 1950, HR@10: 0.1405, NDCG@10: 0.0645
# Validated users: 1960, HR@10: 0.1403, NDCG@10: 0.0647
# Validated users: 1970, HR@10: 0.1401, NDCG@10: 0.0645
# Validated users: 3340, HR@10: 0.1392, NDCG@10: 0.0654
# Validated users: 3350, HR@10: 0.1391, NDCG@10: 0.0653
# Validated users: 3360, HR@10: 0.1387, NDCG@10: 0.0651
# Validated users: 3370, HR@10: 0.1383, NDCG@10: 0.0649
# Validated users: 3380, HR@10: 0.1388, NDCG@10: 0.0651
# Validated users: 3390, HR@10: 0.1389, NDCG@10: 0.0651
# Validated users: 3400, HR@10: 0.1391, NDCG@10: 0.0651
# Validated users: 3410, HR@10: 0.1396, NDCG@10: 0.0652
# Validated users: 3420, HR@10: 0.1398, NDCG@10: 0.0652
# Validated users: 3430, HR@10: 0.1394, NDCG@10: 0.0650
# Validated users: 3440, HR@10: 0.1392, NDCG@10: 0.0649
# Validated users: 3450, HR@10: 0.1397, NDCG@10: 0.0651
# Validated users: 3460, HR@10: 0.1396, NDCG@10: 0.0650
# Validated users: 3470, HR@10: 0.1392, NDCG@10: 0.0648
# Validated users: 3480, HR@10: 0.1394, NDCG@10: 0.0651
# Validated users: 3490, HR@10: 0.1393, NDCG@10: 0.0650
# Validated users: 3500, HR@10: 0.1389, NDCG@10: 0.0648
# Validated users: 3510, HR@10: 0.1393, NDCG@10: 0.0649
# Validated users: 3520, HR@10: 0.1389, NDCG@10: 0.0647
# Validated users: 3530, HR@10: 0.1391, NDCG@10: 0.0651
# Validated users: 3540, HR@10: 0.1387, NDCG@10: 0.0649
# Validated users: 3550, HR@10: 0.1392, NDCG@10: 0.0651
# Validated users: 3560, HR@10: 0.1388, NDCG@10: 0.0649
# Validated users: 3570, HR@10: 0.1389, NDCG@10: 0.0649
# Validated users: 3580, HR@10: 0.1394, NDCG@10: 0.0652
# Validated users: 3590, HR@10: 0.1396, NDCG@10: 0.0652
# Validated users: 3600, HR@10: 0.1394, NDCG@10: 0.0652
# Validated users: 3610, HR@10: 0.1396, NDCG@10: 0.0654
# Validated users: 3620, HR@10: 0.1392, NDCG@10: 0.0653
# Validated users: 3630, HR@10: 0.1394, NDCG@10: 0.0654
# Validated users: 3640, HR@10: 0.1396, NDCG@10: 0.0655
# Validated users: 3650, HR@10: 0.1392, NDCG@10: 0.0653
# Validated users: 3660, HR@10: 0.1393, NDCG@10: 0.0653
# Validated users: 3670, HR@10: 0.1395, NDCG@10: 0.0653
# Validated users: 3680, HR@10: 0.1397, NDCG@10: 0.0654
# Validated users: 3690, HR@10: 0.1398, NDCG@10: 0.0654
# Validated users: 3700, HR@10: 0.1397, NDCG@10: 0.0653
# Validated users: 3710, HR@10: 0.1396, NDCG@10: 0.0652
# Validated users: 3720, HR@10: 0.1395, NDCG@10: 0.0651
# Validated users: 3730, HR@10: 0.1391, NDCG@10: 0.0650
# Validated users: 3740, HR@10: 0.1393, NDCG@10: 0.0650
# Validated users: 3750, HR@10: 0.1395, NDCG@10: 0.0651
# Validated users: 3760, HR@10: 0.1394, NDCG@10: 0.0650
# Validated users: 3770, HR@10: 0.1393, NDCG@10: 0.0649
# Validated users: 3780, HR@10: 0.1402, NDCG@10: 0.0655
# Validated users: 3790, HR@10: 0.1412, NDCG@10: 0.0659
# Validated users: 5150, HR@10: 0.1423, NDCG@10: 0.0666
# Validated users: 5160, HR@10: 0.1424, NDCG@10: 0.0666
# Validated users: 5170, HR@10: 0.1427, NDCG@10: 0.0668
# Validated users: 5180, HR@10: 0.1431, NDCG@10: 0.0670
# Validated users: 5190, HR@10: 0.1428, NDCG@10: 0.0669
# Validated users: 5200, HR@10: 0.1429, NDCG@10: 0.0670
# Validated users: 5210, HR@10: 0.1430, NDCG@10: 0.0672
# Validated users: 5220, HR@10: 0.1429, NDCG@10: 0.0672
# Validated users: 5230, HR@10: 0.1428, NDCG@10: 0.0671
# Validated users: 5240, HR@10: 0.1426, NDCG@10: 0.0670
# Validated users: 5250, HR@10: 0.1423, NDCG@10: 0.0668
# Validated users: 5260, HR@10: 0.1424, NDCG@10: 0.0669
# Validated users: 5270, HR@10: 0.1427, NDCG@10: 0.0670
# Validated users: 5280, HR@10: 0.1424, NDCG@10: 0.0668
# Validated users: 5290, HR@10: 0.1423, NDCG@10: 0.0668
# Validated users: 5300, HR@10: 0.1426, NDCG@10: 0.0669
# Validated users: 5310, HR@10: 0.1427, NDCG@10: 0.0669
# Validated users: 5320, HR@10: 0.1432, NDCG@10: 0.0672
# Validated users: 5330, HR@10: 0.1432, NDCG@10: 0.0671
# Validated users: 5340, HR@10: 0.1429, NDCG@10: 0.0670
# Validated users: 5350, HR@10: 0.1430, NDCG@10: 0.0670
# Validated users: 5360, HR@10: 0.1433, NDCG@10: 0.0670
# Validated users: 5370, HR@10: 0.1430, NDCG@10: 0.0669
# Validated users: 5380, HR@10: 0.1433, NDCG@10: 0.0671
# Validated users: 5390, HR@10: 0.1430, NDCG@10: 0.0670
# Validated users: 5400, HR@10: 0.1430, NDCG@10: 0.0669
# Validated users: 5410, HR@10: 0.1427, NDCG@10: 0.0668
# Validated users: 5420, HR@10: 0.1428, NDCG@10: 0.0668
# Validated users: 5430, HR@10: 0.1427, NDCG@10: 0.0667
# Validated users: 5440, HR@10: 0.1426, NDCG@10: 0.0667
# Validated users: 5450, HR@10: 0.1426, NDCG@10: 0.0666
# Validated users: 5460, HR@10: 0.1423, NDCG@10: 0.0665
# Validated users: 5470, HR@10: 0.1420, NDCG@10: 0.0664
# Validated users: 5480, HR@10: 0.1422, NDCG@10: 0.0664
# Validated users: 5490, HR@10: 0.1421, NDCG@10: 0.0664
# Validated users: 5500, HR@10: 0.1420, NDCG@10: 0.0663
# Validated users: 5510, HR@10: 0.1423, NDCG@10: 0.0664
# Validated users: 5520, HR@10: 0.1422, NDCG@10: 0.0664
# Validated users: 5530, HR@10: 0.1421, NDCG@10: 0.0663
# Validated users: 5540, HR@10: 0.1422, NDCG@10: 0.0663
# Validated users: 5550, HR@10: 0.1422, NDCG@10: 0.0663
# Validated users: 5560, HR@10: 0.1423, NDCG@10: 0.0663
# Validated users: 5570, HR@10: 0.1422, NDCG@10: 0.0663
# Validated users: 5580, HR@10: 0.1421, NDCG@10: 0.0663
# Validated users: 5590, HR@10: 0.1420, NDCG@10: 0.0663
# Validated users: 5600, HR@10: 0.1420, NDCG@10: 0.0663
# Validated users: 8320, HR@10: 0.1437, NDCG@10: 0.0671
# Validated users: 8330, HR@10: 0.1437, NDCG@10: 0.0670
# Validated users: 8340, HR@10: 0.1436, NDCG@10: 0.0670
# Validated users: 8350, HR@10: 0.1436, NDCG@10: 0.0670
# Validated users: 8360, HR@10: 0.1434, NDCG@10: 0.0669
# Validated users: 8370, HR@10: 0.1436, NDCG@10: 0.0670
# Validated users: 8380, HR@10: 0.1437, NDCG@10: 0.0670
# Validated users: 8390, HR@10: 0.1436, NDCG@10: 0.0670
# Validated users: 8400, HR@10: 0.1437, NDCG@10: 0.0670
# Validated users: 8410, HR@10: 0.1438, NDCG@10: 0.0670
# Validated users: 8420, HR@10: 0.1437, NDCG@10: 0.0670
# Validated users: 8430, HR@10: 0.1437, NDCG@10: 0.0669
# Validated users: 8440, HR@10: 0.1437, NDCG@10: 0.0669
# Validated users: 8450, HR@10: 0.1436, NDCG@10: 0.0668
# Validated users: 8460, HR@10: 0.1434, NDCG@10: 0.0668
# Validated users: 8470, HR@10: 0.1432, NDCG@10: 0.0667
# Validated users: 8480, HR@10: 0.1435, NDCG@10: 0.0668
# Validated users: 8490, HR@10: 0.1435, NDCG@10: 0.0668
# Validated users: 8500, HR@10: 0.1436, NDCG@10: 0.0668
# Validated users: 8510, HR@10: 0.1436, NDCG@10: 0.0668
# Validated users: 8520, HR@10: 0.1434, NDCG@10: 0.0667
# Validated users: 8530, HR@10: 0.1435, NDCG@10: 0.0667
# Validated users: 8540, HR@10: 0.1433, NDCG@10: 0.0666
# Validated users: 8550, HR@10: 0.1433, NDCG@10: 0.0667
# Validated users: 8560, HR@10: 0.1433, NDCG@10: 0.0667
# Validated users: 8570, HR@10: 0.1435, NDCG@10: 0.0668
# Validated users: 8580, HR@10: 0.1435, NDCG@10: 0.0668
# Validated users: 8590, HR@10: 0.1437, NDCG@10: 0.0668
# Validated users: 8600, HR@10: 0.1436, NDCG@10: 0.0668
# Validated users: 8610, HR@10: 0.1434, NDCG@10: 0.0667
# Validated users: 8620, HR@10: 0.1435, NDCG@10: 0.0668
# Validated users: 8630, HR@10: 0.1433, NDCG@10: 0.0668
# Validated users: 8640, HR@10: 0.1433, NDCG@10: 0.0667
# Validated users: 8650, HR@10: 0.1434, NDCG@10: 0.0668
# Validated users: 8660, HR@10: 0.1432, NDCG@10: 0.0667
# Validated users: 8670, HR@10: 0.1431, NDCG@10: 0.0667
# Validated users: 8680, HR@10: 0.1433, NDCG@10: 0.0668
# Validated users: 8690, HR@10: 0.1433, NDCG@10: 0.0669
# Validated users: 8700, HR@10: 0.1432, NDCG@10: 0.0668
# Validated users: 8710, HR@10: 0.1434, NDCG@10: 0.0669
# Validated users: 8720, HR@10: 0.1432, NDCG@10: 0.0669
# Validated users: 8730, HR@10: 0.1432, NDCG@10: 0.0668
# Validated users: 8740, HR@10: 0.1431, NDCG@10: 0.0668
# Validated users: 8750, HR@10: 0.1432, NDCG@10: 0.0669
# Validated users: 8760, HR@10: 0.1430, NDCG@10: 0.0668
# Validated users: 8770, HR@10: 0.1434, NDCG@10: 0.0670
# Validated users: 24680, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24690, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24700, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24710, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24720, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24730, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24740, HR@10: 0.1389, NDCG@10: 0.0655
# Validated users: 24750, HR@10: 0.1389, NDCG@10: 0.0655
# Validated users: 24760, HR@10: 0.1389, NDCG@10: 0.0655
# Validated users: 24770, HR@10: 0.1388, NDCG@10: 0.0655
# Validated users: 24780, HR@10: 0.1388, NDCG@10: 0.0655
# Validated users: 24790, HR@10: 0.1388, NDCG@10: 0.0655
# Validated users: 24800, HR@10: 0.1388, NDCG@10: 0.0655
# Validated users: 24810, HR@10: 0.1389, NDCG@10: 0.0655
# Validated users: 24820, HR@10: 0.1388, NDCG@10: 0.0655
# Validated users: 24830, HR@10: 0.1389, NDCG@10: 0.0655
# Validated users: 24840, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24850, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24860, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24870, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24880, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24890, HR@10: 0.1390, NDCG@10: 0.0655
# Validated users: 24900, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24910, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24920, HR@10: 0.1392, NDCG@10: 0.0656
# Validated users: 24930, HR@10: 0.1391, NDCG@10: 0.0657
# Validated users: 24940, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24950, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24960, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24970, HR@10: 0.1390, NDCG@10: 0.0656
# Validated users: 24980, HR@10: 0.1391, NDCG@10: 0.0656
# Validated users: 24990, HR@10: 0.1391, NDCG@10: 0.0656
# HR@10: 0.1390, NDCG@10: 0.0656

# %%
import torch
def shift_right(x: torch.Tensor):
    """
    This method shifts $i^{th}$ row of a matrix by $i$ columns.

    If the input is `[[1, 2 ,3], [4, 5 ,6], [7, 8, 9]]`, the shifted
    result would be `[[1, 2 ,3], [0, 4, 5], [6, 0, 7]]`.
    *Ideally we should mask out the lower triangle but it's ok for our purpose*.
    """

    # Concatenate a column of zeros
    zero_pad = x.new_zeros(x.shape[0], 1, *x.shape[2:])
    x_padded = torch.cat([x, zero_pad], dim=1)

    # Reshape and remove excess elements from the end
    x_padded = x_padded.view(x.shape[1] + 1, x.shape[0], *x.shape[2:])
    x = x_padded[:-1].view_as(x)

    #
    return x

x= [[1, 2 ,3], [4, 5 ,6], [7, 8, 9]]
print(shift_right(torch.tensor(x)))
# Out:
# tensor([[1, 2, 3],
#         [0, 4, 5],
#         [6, 0, 7]])
